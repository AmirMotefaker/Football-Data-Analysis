# %% [markdown]
# Football Club Market Value 2021

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %%
df = pd.read_csv('E:\\AMotefaker\\ABC\\FPA\\Football Club Market Value 2021\\club.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Club Name                                       100 non-null    object
#  1   Competition Name                                100 non-null    object
#  2   Squad Size                                      100 non-null    int64
#  3   Average Age Of Players                          100 non-null    float64
#  4   Market Value Of Club In Millions(£)             100 non-null    float64
#  5   Average Market Value Of Players In Millions(£)  100 non-null    float64
#  6   Market Value Of Top 18 Players In Millions(£)   100 non-null    float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#        Squad Size  Average Age Of Players  \
# count  100.000000              100.000000
# mean    27.740000               26.368000
# std      2.812742                1.417701
# min     22.000000               23.000000
# 25%     26.000000               25.575000
# 50%     27.000000               26.200000
# 75%     29.000000               27.500000
# max     36.000000               30.100000
#
#        Market Value Of Club In Millions(£)  \
# count                           100.000000
# mean                            263.793800
# std                             205.457212
# min                              86.940000
# 25%                             114.147500
# 50%                             182.060000
# 75%                             345.622500
# max                             970.020000
#
#        Average Market Value Of Players In Millions(£)  \
# count                                      100.000000
# mean                                         9.682600
# std                                          7.747373
# min                                          2.560000
# 25%                                          4.127500
# 50%                                          7.045000
# 75%                                         12.980000
# max                                         40.420000
#
#        Market Value Of Top 18 Players In Millions(£)
# count                                     100.000000
# mean                                      243.451700
# std                                       190.344411
# min                                        72.270000
# 25%                                       105.795000
# 50%                                       170.550000
# 75%                                       321.412500
# max                                       920.700000

# %%
df.head()
# Out:
#              Club Name Competition Name  Squad Size  Average Age Of Players  \
# 0      Manchester City   Premier League          24                    27.1
# 1  Paris Saint-Germain          Ligue 1          36                    26.1
# 2    Manchester United   Premier League          29                    27.9
# 3           Chelsea FC   Premier League          27                    26.9
# 4         Liverpool FC   Premier League          27                    27.2
#
#    Market Value Of Club In Millions(£)  \
# 0                               970.02
# 1                               891.18
# 2                               820.13
# 3                               802.35
# 4                               779.85
#
#    Average Market Value Of Players In Millions(£)  \
# 0                                           40.42
# 1                                           24.76
# 2                                           28.28
# 3                                           29.72
# 4                                           28.88
#
#    Market Value Of Top 18 Players In Millions(£)
# 0                                         920.70
# 1                                         801.00
# 2                                         742.50
# 3                                         737.10
# 4                                         715.95

# %% [markdown]
# Creating Special DataFrame

# %%
ls = df['Competition Name'].value_counts().index.to_list()
ls1 = df['Competition Name'].value_counts().values
temp = []
temp1= []
for i in range(len(ls)):
    temp.append(ls[i])
    temp1.append(ls1[i])
dict = {'Competition Name' : temp, 'Count' : ls1}
df1 = pd.DataFrame(dict)

temp = df.groupby('Competition Name').mean()
ls = temp['Squad Size'].index.to_list()
squad = temp['Squad Size'].values
avg_age = temp['Average Age Of Players'].values
club_val = temp['Market Value Of Club In Millions(£)'].values
mv = temp['Average Market Value Of Players In Millions(£)'].values
mv18 = temp['Market Value Of Top 18 Players In Millions(£)'].values
temp = []
temp1= []
temp2 = []
temp3= []
temp4 = []
temp5 = []
for i in range(len(ls)):
    temp.append(ls[i])
    temp1.append(squad[i])
    temp2.append(avg_age[i])
    temp3.append(club_val[i])
    temp4.append(mv[i])
    temp5.append(mv18[i])
dict1 = {'Competition Name' : temp, 'Avg Squad Size' : temp1, 'Avg Age Of Players':temp2,'Avg Market Value Of ClubsIn Millions(£)' : temp3, 'Avg Market Value Of Players In Millions(£)':temp4, 'Avg Market Value Of Top 18 Players In Millions(£)':temp5}
df2 = pd.DataFrame(dict1)

# %% [markdown]
# Competition Count

# %%
fig = px.bar(df1, y= 'Count' ,x = 'Competition Name', color= 'Competition Name')
fig.update_layout(showlegend=False)
fig.show()
plt.savefig('Competition Count.svg', dpi=1200)

# %% [markdown]
# Competition Mean Stats

# %%
fig = px.bar(df2, y= 'Avg Squad Size' ,x = 'Competition Name', color= 'Competition Name')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="c2125f7a-bd7c-4b4a-90f3-6a26630f06e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2125f7a-bd7c-4b4a-90f3-6a26630f06e5")) {                    Plotly.newPlot(                        "c2125f7a-bd7c-4b4a-90f3-6a26630f06e5",                        [{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1.HNL","offsetgroup":"1.HNL","orientation":"v","showlegend":true,"textposition":"auto","x":["1.HNL"],"xaxis":"x","y":[30.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bundesliga","offsetgroup":"Bundesliga","orientation":"v","showlegend":true,"textposition":"auto","x":["Bundesliga"],"xaxis":"x","y":[29.53846153846154],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Championship","offsetgroup":"Championship","orientation":"v","showlegend":true,"textposition":"auto","x":["Championship"],"xaxis":"x","y":[28.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Eredivisie","offsetgroup":"Eredivisie","orientation":"v","showlegend":true,"textposition":"auto","x":["Eredivisie"],"xaxis":"x","y":[26.666666666666668],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Jupiler Pro League","offsetgroup":"Jupiler Pro League","orientation":"v","showlegend":true,"textposition":"auto","x":["Jupiler Pro League"],"xaxis":"x","y":[27.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"LaLiga","offsetgroup":"LaLiga","orientation":"v","showlegend":true,"textposition":"auto","x":["LaLiga"],"xaxis":"x","y":[25.923076923076923],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Liga Bwin","offsetgroup":"Liga Bwin","orientation":"v","showlegend":true,"textposition":"auto","x":["Liga Bwin"],"xaxis":"x","y":[27.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Liga Profesional","offsetgroup":"Liga Profesional","orientation":"v","showlegend":true,"textposition":"auto","x":["Liga Profesional"],"xaxis":"x","y":[29.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Ligue 1","offsetgroup":"Ligue 1","orientation":"v","showlegend":true,"textposition":"auto","x":["Ligue 1"],"xaxis":"x","y":[28.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Premier League","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Premier League","offsetgrou ...

# %% [markdown]
# Average market Value of leagues

# %%
fig = px.bar(df2, y= 'Avg Market Value Of ClubsIn Millions(£)' ,x = 'Competition Name', color= 'Competition Name')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="12069b3f-bbf9-4a72-8098-be3fbee8d560" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12069b3f-bbf9-4a72-8098-be3fbee8d560")) {                    Plotly.newPlot(                        "12069b3f-bbf9-4a72-8098-be3fbee8d560",                        [{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1.HNL","offsetgroup":"1.HNL","orientation":"v","showlegend":true,"textposition":"auto","x":["1.HNL"],"xaxis":"x","y":[98.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bundesliga","offsetgroup":"Bundesliga","orientation":"v","showlegend":true,"textposition":"auto","x":["Bundesliga"],"xaxis":"x","y":[275.4915384615384],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Championship","offsetgroup":"Championship","orientation":"v","showlegend":true,"textposition":"auto","x":["Championship"],"xaxis":"x","y":[116.46333333333332],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Eredivisie","offsetgroup":"Eredivisie","orientation":"v","showlegend":true,"textposition":"auto","x":["Eredivisie"],"xaxis":"x","y":[181.30666666666664],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Jupiler Pro League","offsetgroup":"Jupiler Pro League","orientation":"v","showlegend":true,"textposition":"auto","x":["Jupiler Pro League"],"xaxis":"x","y":[135.47500000000002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"LaLiga","offsetgroup":"LaLiga","orientation":"v","showlegend":true,"textposition":"auto","x":["LaLiga"],"xaxis":"x","y":[309.8007692307692],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Liga Bwin","offsetgroup":"Liga Bwin","orientation":"v","showlegend":true,"textposition":"auto","x":["Liga Bwin"],"xaxis":"x","y":[194.4475],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Liga Profesional","offsetgroup":"Liga Profesional","orientation":"v","showlegend":true,"textposition":"auto","x":["Liga Profesional"],"xaxis":"x","y":[100.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Ligue 1","offsetgroup":"Ligue 1","orientation":"v","showlegend":true,"tex ...

# %% [markdown]
# Average age Of Players

# %%
fig = px.bar(df2, y= 'Avg Age Of Players' ,x = 'Competition Name', color= 'Competition Name')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="df25e648-2459-4cd5-90a7-d2c403dc0896" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df25e648-2459-4cd5-90a7-d2c403dc0896")) {                    Plotly.newPlot(                        "df25e648-2459-4cd5-90a7-d2c403dc0896",                        [{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1.HNL","offsetgroup":"1.HNL","orientation":"v","showlegend":true,"textposition":"auto","x":["1.HNL"],"xaxis":"x","y":[26.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bundesliga","offsetgroup":"Bundesliga","orientation":"v","showlegend":true,"textposition":"auto","x":["Bundesliga"],"xaxis":"x","y":[25.053846153846152],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Championship","offsetgroup":"Championship","orientation":"v","showlegend":true,"textposition":"auto","x":["Championship"],"xaxis":"x","y":[26.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Eredivisie","offsetgroup":"Eredivisie","orientation":"v","showlegend":true,"textposition":"auto","x":["Eredivisie"],"xaxis":"x","y":[24.833333333333332],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Jupiler Pro League","offsetgroup":"Jupiler Pro League","orientation":"v","showlegend":true,"textposition":"auto","x":["Jupiler Pro League"],"xaxis":"x","y":[23.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"LaLiga","offsetgroup":"LaLiga","orientation":"v","showlegend":true,"textposition":"auto","x":["LaLiga"],"xaxis":"x","y":[27.36923076923077],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Liga Bwin","offsetgroup":"Liga Bwin","orientation":"v","showlegend":true,"textposition":"auto","x":["Liga Bwin"],"xaxis":"x","y":[26.225],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Liga Profesional","offsetgroup":"Liga Profesional","orientation":"v","showlegend":true,"textposition":"auto","x":["Liga Profesional"],"xaxis":"x","y":[27.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Ligue 1","offsetgroup":"Ligue 1","orientation":"v","showlegend":true,"textposition":"auto","x":["Ligue 1"],"xaxis":"x","y":[24.84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Competition Name=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Premier League","marker":{"color":"#FECB52","pattern":{"shap ...

# %% [markdown]
# Average age of players vs player values

# %%
fig = px.scatter(df2, y="Avg Age Of Players", x="Avg Market Value Of Players In Millions(£)", color="Competition Name", symbol="Competition Name")
fig.update_traces(marker_size=10)
fig.show()
# Out:
# <div>                            <div id="5bd36fe8-845b-4d33-bea0-4872a1686aeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bd36fe8-845b-4d33-bea0-4872a1686aeb")) {                    Plotly.newPlot(                        "5bd36fe8-845b-4d33-bea0-4872a1686aeb",                        [{"hovertemplate":"Competition Name=1.HNL<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"1.HNL","orientation":"v","showlegend":true,"x":[3.29],"xaxis":"x","y":[26.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Bundesliga<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","symbol":"diamond","size":10},"mode":"markers","name":"Bundesliga","orientation":"v","showlegend":true,"x":[9.433846153846154],"xaxis":"x","y":[25.053846153846152],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Championship<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","symbol":"square","size":10},"mode":"markers","name":"Championship","orientation":"v","showlegend":true,"x":[4.146666666666667],"xaxis":"x","y":[26.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Eredivisie<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","symbol":"x","size":10},"mode":"markers","name":"Eredivisie","orientation":"v","showlegend":true,"x":[6.973333333333333],"xaxis":"x","y":[24.833333333333332],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Jupiler Pro League<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","symbol":"cross","size":10},"mode":"markers","name":"Jupiler Pro League","orientation":"v","showlegend":true,"x":[4.915],"xaxis":"x","y":[23.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=LaLiga<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","symbol":"circle","size":10},"mode":"markers","name":"LaLiga","orientation":"v","showlegend":true,"x":[11.986153846153845],"xaxis":"x","y":[27.36923076923077],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Liga Bwin<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","symbol":"diamond","size":10},"mode":"markers","name":"Liga Bwin","orientation":"v","showlegend":true,"x":[7.21],"xaxis":"x","y":[26.225],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Liga Profesional<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","symbol":"square","size":10},"mode":"markers","name":"Liga Profesional","orientation":"v","showlegend":true,"x":[3.45],"xaxis":"x","y":[27.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Ligue 1<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Age Of Players=%{y}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","symbol":"x","size":10},"mode":"markers","name":"Ligue 1","orientation":"v","showlegend":true,"x":[8.771],"xaxis":"x","y":[24.84],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Premier League<br>Avg Market Value Of Pla ...

# %% [markdown]
# Average squad size vs Average player value

# %%
fig = px.scatter(df2, y="Avg Squad Size", x="Avg Market Value Of Players In Millions(£)", color="Competition Name", symbol="Competition Name")
fig.update_traces(marker_size=10)
fig.show()
# Out:
# <div>                            <div id="715cf991-0c68-4f44-8806-821f602e7b74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("715cf991-0c68-4f44-8806-821f602e7b74")) {                    Plotly.newPlot(                        "715cf991-0c68-4f44-8806-821f602e7b74",                        [{"hovertemplate":"Competition Name=1.HNL<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"1.HNL","orientation":"v","showlegend":true,"x":[3.29],"xaxis":"x","y":[30.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Bundesliga<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","symbol":"diamond","size":10},"mode":"markers","name":"Bundesliga","orientation":"v","showlegend":true,"x":[9.433846153846154],"xaxis":"x","y":[29.53846153846154],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Championship<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","symbol":"square","size":10},"mode":"markers","name":"Championship","orientation":"v","showlegend":true,"x":[4.146666666666667],"xaxis":"x","y":[28.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Eredivisie<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","symbol":"x","size":10},"mode":"markers","name":"Eredivisie","orientation":"v","showlegend":true,"x":[6.973333333333333],"xaxis":"x","y":[26.666666666666668],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Jupiler Pro League<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","symbol":"cross","size":10},"mode":"markers","name":"Jupiler Pro League","orientation":"v","showlegend":true,"x":[4.915],"xaxis":"x","y":[27.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=LaLiga<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","symbol":"circle","size":10},"mode":"markers","name":"LaLiga","orientation":"v","showlegend":true,"x":[11.986153846153845],"xaxis":"x","y":[25.923076923076923],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Liga Bwin<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","symbol":"diamond","size":10},"mode":"markers","name":"Liga Bwin","orientation":"v","showlegend":true,"x":[7.21],"xaxis":"x","y":[27.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Liga Profesional<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","symbol":"square","size":10},"mode":"markers","name":"Liga Profesional","orientation":"v","showlegend":true,"x":[3.45],"xaxis":"x","y":[29.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Ligue 1<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","symbol":"x","size":10},"mode":"markers","name":"Ligue 1","orientation":"v","showlegend":true,"x":[8.771],"xaxis":"x","y":[28.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Premier League<br>Avg Market Value Of Players In Millions(\u00a3)=%{x}<br>Avg Sq ...

# %% [markdown]
# Average club value vs squad sizes

# %%
fig = px.scatter(df2, y="Avg Squad Size", x="Avg Market Value Of ClubsIn Millions(£)", color="Competition Name", symbol="Competition Name")
fig.update_traces(marker_size=10)
fig.show()
# Out:
# <div>                            <div id="a057fc80-2959-45aa-9b59-c0b5815960a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a057fc80-2959-45aa-9b59-c0b5815960a2")) {                    Plotly.newPlot(                        "a057fc80-2959-45aa-9b59-c0b5815960a2",                        [{"hovertemplate":"Competition Name=1.HNL<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"1.HNL","orientation":"v","showlegend":true,"x":[98.82],"xaxis":"x","y":[30.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Bundesliga<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","symbol":"diamond","size":10},"mode":"markers","name":"Bundesliga","orientation":"v","showlegend":true,"x":[275.4915384615384],"xaxis":"x","y":[29.53846153846154],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Championship<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","symbol":"square","size":10},"mode":"markers","name":"Championship","orientation":"v","showlegend":true,"x":[116.46333333333332],"xaxis":"x","y":[28.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Eredivisie<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","symbol":"x","size":10},"mode":"markers","name":"Eredivisie","orientation":"v","showlegend":true,"x":[181.30666666666664],"xaxis":"x","y":[26.666666666666668],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Jupiler Pro League<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","symbol":"cross","size":10},"mode":"markers","name":"Jupiler Pro League","orientation":"v","showlegend":true,"x":[135.47500000000002],"xaxis":"x","y":[27.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=LaLiga<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","symbol":"circle","size":10},"mode":"markers","name":"LaLiga","orientation":"v","showlegend":true,"x":[309.8007692307692],"xaxis":"x","y":[25.923076923076923],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Liga Bwin<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","symbol":"diamond","size":10},"mode":"markers","name":"Liga Bwin","orientation":"v","showlegend":true,"x":[194.4475],"xaxis":"x","y":[27.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Liga Profesional<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","symbol":"square","size":10},"mode":"markers","name":"Liga Profesional","orientation":"v","showlegend":true,"x":[100.04],"xaxis":"x","y":[29.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Ligue 1<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Size=%{y}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","symbol":"x","size":10},"mode":"markers","name":"Ligue 1","orientation":"v","showlegend":true,"x":[264.633],"xaxis":"x","y":[28.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Competition Name=Premier League<br>Avg Market Value Of ClubsIn Millions(\u00a3)=%{x}<br>Avg Squad Siz ...

# %% [markdown]
# Average Age Of Players vs Squad Size vs Average Market value Of Players

# %%
fig = px.scatter_3d(df2, x='Avg Squad Size', y='Avg Age Of Players', z='Avg Market Value Of Players In Millions(£)', color='Competition Name')
fig.show()
# Out:
# <div>                            <div id="e474f3cf-fbf6-4978-9314-092a4118eeef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e474f3cf-fbf6-4978-9314-092a4118eeef")) {                    Plotly.newPlot(                        "e474f3cf-fbf6-4978-9314-092a4118eeef",                        [{"hovertemplate":"Competition Name=1.HNL<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"1.HNL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"1.HNL","scene":"scene","showlegend":true,"x":[30.0],"y":[26.1],"z":[3.29],"type":"scatter3d"},{"hovertemplate":"Competition Name=Bundesliga<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Bundesliga","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Bundesliga","scene":"scene","showlegend":true,"x":[29.53846153846154],"y":[25.053846153846152],"z":[9.433846153846154],"type":"scatter3d"},{"hovertemplate":"Competition Name=Championship<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Championship","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Championship","scene":"scene","showlegend":true,"x":[28.0],"y":[26.8],"z":[4.146666666666667],"type":"scatter3d"},{"hovertemplate":"Competition Name=Eredivisie<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Eredivisie","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Eredivisie","scene":"scene","showlegend":true,"x":[26.666666666666668],"y":[24.833333333333332],"z":[6.973333333333333],"type":"scatter3d"},{"hovertemplate":"Competition Name=Jupiler Pro League<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Jupiler Pro League","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Jupiler Pro League","scene":"scene","showlegend":true,"x":[27.5],"y":[23.8],"z":[4.915],"type":"scatter3d"},{"hovertemplate":"Competition Name=LaLiga<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"LaLiga","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"LaLiga","scene":"scene","showlegend":true,"x":[25.923076923076923],"y":[27.36923076923077],"z":[11.986153846153845],"type":"scatter3d"},{"hovertemplate":"Competition Name=Liga Bwin<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Liga Bwin","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Liga Bwin","scene":"scene","showlegend":true,"x":[27.0],"y":[26.225],"z":[7.21],"type":"scatter3d"},{"hovertemplate":"Competition Name=Liga Profesional<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Liga Profesional","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Liga Profesional","scene":"scene","showlegend":true,"x":[29.0],"y":[27.9],"z":[3.45],"type":"scatter3d"},{"hovertemplate":"Competition Name=Ligue 1<br>Avg Squad Size=%{x}<br>Avg Age Of Players=%{y}<br>Avg Market Value Of Players In Millions(\u00a3)=%{z}<extra></extra>","legendgroup":"Ligue 1","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Ligue 1","scene":"scene","showlegend":true,"x":[28.8],"y":[24.84],"z":[8.771],"type":"scatter3d"},{"hovertemplate":"Competit ...

# %% [markdown]
# Club market value in Millions(£)

# %%
fig = px.bar(df, y= 'Market Value Of Club In Millions(£)' ,x = 'Club Name', color= 'Club Name')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="fb87c37c-7d8b-4fea-9cce-13fe132197c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb87c37c-7d8b-4fea-9cce-13fe132197c1")) {                    Plotly.newPlot(                        "fb87c37c-7d8b-4fea-9cce-13fe132197c1",                        [{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Manchester City","offsetgroup":"Manchester City","orientation":"v","showlegend":true,"textposition":"auto","x":["Manchester City"],"xaxis":"x","y":[970.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paris Saint-Germain","offsetgroup":"Paris Saint-Germain","orientation":"v","showlegend":true,"textposition":"auto","x":["Paris Saint-Germain"],"xaxis":"x","y":[891.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Manchester United","offsetgroup":"Manchester United","orientation":"v","showlegend":true,"textposition":"auto","x":["Manchester United"],"xaxis":"x","y":[820.13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chelsea FC","offsetgroup":"Chelsea FC","orientation":"v","showlegend":true,"textposition":"auto","x":["Chelsea FC"],"xaxis":"x","y":[802.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Liverpool FC","offsetgroup":"Liverpool FC","orientation":"v","showlegend":true,"textposition":"auto","x":["Liverpool FC"],"xaxis":"x","y":[779.85],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bayern Munich","offsetgroup":"Bayern Munich","orientation":"v","showlegend":true,"textposition":"auto","x":["Bayern Munich"],"xaxis":"x","y":[756.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Real Madrid","offsetgroup":"Real Madrid","orientation":"v","showlegend":true,"textposition":"auto","x":["Real Madrid"],"xaxis":"x","y":[680.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Atl\u00e9tico de Madrid","offsetgroup":"Atl\u00e9tico de Madrid","orientation":"v","showlegend":true,"textposition":"auto","x":["Atl\u00e9tico de Madrid"],"xaxis":"x","y":[671.31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Tottenham Hotspur","offsetgroup":"Tottenham Hotspur","orientation":"v","showlegend":tr ...

# %% [markdown]
# Squad size of the club is the number of players

# %%
fig = px.bar(df, y= 'Squad Size' ,x = 'Club Name', color= 'Club Name')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <div>                            <div id="cf6d8d67-9d7f-47e5-b345-0b0e28a3b66a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf6d8d67-9d7f-47e5-b345-0b0e28a3b66a")) {                    Plotly.newPlot(                        "cf6d8d67-9d7f-47e5-b345-0b0e28a3b66a",                        [{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Manchester City","offsetgroup":"Manchester City","orientation":"v","showlegend":true,"textposition":"auto","x":["Manchester City"],"xaxis":"x","y":[24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paris Saint-Germain","offsetgroup":"Paris Saint-Germain","orientation":"v","showlegend":true,"textposition":"auto","x":["Paris Saint-Germain"],"xaxis":"x","y":[36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Manchester United","offsetgroup":"Manchester United","orientation":"v","showlegend":true,"textposition":"auto","x":["Manchester United"],"xaxis":"x","y":[29],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chelsea FC","offsetgroup":"Chelsea FC","orientation":"v","showlegend":true,"textposition":"auto","x":["Chelsea FC"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Liverpool FC","offsetgroup":"Liverpool FC","orientation":"v","showlegend":true,"textposition":"auto","x":["Liverpool FC"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bayern Munich","offsetgroup":"Bayern Munich","orientation":"v","showlegend":true,"textposition":"auto","x":["Bayern Munich"],"xaxis":"x","y":[26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Real Madrid","offsetgroup":"Real Madrid","orientation":"v","showlegend":true,"textposition":"auto","x":["Real Madrid"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Atl\u00e9tico de Madrid","offsetgroup":"Atl\u00e9tico de Madrid","orientation":"v","showlegend":true,"textposition":"auto","x":["Atl\u00e9tico de Madrid"],"xaxis":"x","y":[22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Tottenham Hotspur","offsetgroup":"Tottenham Hotspur","orientation":"v","showlegend":true,"textposition":"auto","x":["Tottenham Hotspur"],"xaxis":"x","y":[24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Club Name=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"FC Barcelona","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"FC Barcelona","offsetg ...

# %%
df.columns
# Out:
# Index(['Club Name', 'Competition Name', 'Squad Size', 'Average Age Of Players',
#        'Market Value Of Club In Millions(£)',
#        'Average Market Value Of Players In Millions(£)',
#        'Market Value Of Top 18 Players In Millions(£)'],
#       dtype='object')

# %% [markdown]
# Squad Size Vs Club Value

# %%
fig = px.scatter(df, y="Squad Size", x="Market Value Of Club In Millions(£)", color="Club Name", symbol="Club Name")
fig.update_traces(marker_size=10)
fig.show()
# Out:
# <div>                            <div id="90b6e97d-dcfc-4316-a818-f3da2570ce85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90b6e97d-dcfc-4316-a818-f3da2570ce85")) {                    Plotly.newPlot(                        "90b6e97d-dcfc-4316-a818-f3da2570ce85",                        [{"hovertemplate":"Club Name=Manchester City<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"Manchester City","orientation":"v","showlegend":true,"x":[970.02],"xaxis":"x","y":[24],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Paris Saint-Germain<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","symbol":"diamond","size":10},"mode":"markers","name":"Paris Saint-Germain","orientation":"v","showlegend":true,"x":[891.18],"xaxis":"x","y":[36],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Manchester United<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","symbol":"square","size":10},"mode":"markers","name":"Manchester United","orientation":"v","showlegend":true,"x":[820.13],"xaxis":"x","y":[29],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Chelsea FC<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","symbol":"x","size":10},"mode":"markers","name":"Chelsea FC","orientation":"v","showlegend":true,"x":[802.35],"xaxis":"x","y":[27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Liverpool FC<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","symbol":"cross","size":10},"mode":"markers","name":"Liverpool FC","orientation":"v","showlegend":true,"x":[779.85],"xaxis":"x","y":[27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Bayern Munich<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","symbol":"circle","size":10},"mode":"markers","name":"Bayern Munich","orientation":"v","showlegend":true,"x":[756.45],"xaxis":"x","y":[26],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Real Madrid<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","symbol":"diamond","size":10},"mode":"markers","name":"Real Madrid","orientation":"v","showlegend":true,"x":[680.4],"xaxis":"x","y":[27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Atl\u00e9tico de Madrid<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","symbol":"square","size":10},"mode":"markers","name":"Atl\u00e9tico de Madrid","orientation":"v","showlegend":true,"x":[671.31],"xaxis":"x","y":[22],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Tottenham Hotspur<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","symbol":"x","size":10},"mode":"markers","name":"Tottenham Hotspur","orientation":"v","showlegend":true,"x":[627.3],"xaxis":"x","y":[24],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=FC Barcelona<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Squad Size=%{y}<extra></extra>","legendgroup":"FC Barcelona","marker":{"color":"#FECB52","symbol":"cross","size":10},"mode":"markers","name":"FC Barce ...

# %% [markdown]
# Average Age Of Players vs Club Value

# %%
fig = px.scatter(df, y="Average Age Of Players", x="Market Value Of Club In Millions(£)", color="Club Name", symbol="Club Name")
fig.update_traces(marker_size=10)
fig.show()
# Out:
# <div>                            <div id="31717e64-5444-4ea8-bcd5-3650db153e04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31717e64-5444-4ea8-bcd5-3650db153e04")) {                    Plotly.newPlot(                        "31717e64-5444-4ea8-bcd5-3650db153e04",                        [{"hovertemplate":"Club Name=Manchester City<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"Manchester City","orientation":"v","showlegend":true,"x":[970.02],"xaxis":"x","y":[27.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Paris Saint-Germain<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","symbol":"diamond","size":10},"mode":"markers","name":"Paris Saint-Germain","orientation":"v","showlegend":true,"x":[891.18],"xaxis":"x","y":[26.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Manchester United<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","symbol":"square","size":10},"mode":"markers","name":"Manchester United","orientation":"v","showlegend":true,"x":[820.13],"xaxis":"x","y":[27.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Chelsea FC<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","symbol":"x","size":10},"mode":"markers","name":"Chelsea FC","orientation":"v","showlegend":true,"x":[802.35],"xaxis":"x","y":[26.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Liverpool FC<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","symbol":"cross","size":10},"mode":"markers","name":"Liverpool FC","orientation":"v","showlegend":true,"x":[779.85],"xaxis":"x","y":[27.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Bayern Munich<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","symbol":"circle","size":10},"mode":"markers","name":"Bayern Munich","orientation":"v","showlegend":true,"x":[756.45],"xaxis":"x","y":[26.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Real Madrid<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","symbol":"diamond","size":10},"mode":"markers","name":"Real Madrid","orientation":"v","showlegend":true,"x":[680.4],"xaxis":"x","y":[27.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Atl\u00e9tico de Madrid<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","symbol":"square","size":10},"mode":"markers","name":"Atl\u00e9tico de Madrid","orientation":"v","showlegend":true,"x":[671.31],"xaxis":"x","y":[28.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Tottenham Hotspur<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","symbol":"x","size":10},"mode":"markers","name":"Tottenham Hotspur","orientation":"v","showlegend":true,"x":[627.3],"xaxis":"x","y":[25.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=FC Barcelona<br>Market Value Of Club In Millions(\u00a3)=%{x}<br>Average Age Of Players=% ...

# %% [markdown]
# Average Age Of Players vs Average Market Value Of Players

# %%
fig = px.scatter(df, y="Average Age Of Players", x="Average Market Value Of Players In Millions(£)", color="Club Name", symbol="Club Name")
fig.update_traces(marker_size=10)
fig.show()
# Out:
# <div>                            <div id="5dbb9555-93a7-4cf3-94ef-176668f1c6a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dbb9555-93a7-4cf3-94ef-176668f1c6a4")) {                    Plotly.newPlot(                        "5dbb9555-93a7-4cf3-94ef-176668f1c6a4",                        [{"hovertemplate":"Club Name=Manchester City<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"Manchester City","orientation":"v","showlegend":true,"x":[40.42],"xaxis":"x","y":[27.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Paris Saint-Germain<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","symbol":"diamond","size":10},"mode":"markers","name":"Paris Saint-Germain","orientation":"v","showlegend":true,"x":[24.76],"xaxis":"x","y":[26.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Manchester United<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","symbol":"square","size":10},"mode":"markers","name":"Manchester United","orientation":"v","showlegend":true,"x":[28.28],"xaxis":"x","y":[27.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Chelsea FC<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","symbol":"x","size":10},"mode":"markers","name":"Chelsea FC","orientation":"v","showlegend":true,"x":[29.72],"xaxis":"x","y":[26.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Liverpool FC<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","symbol":"cross","size":10},"mode":"markers","name":"Liverpool FC","orientation":"v","showlegend":true,"x":[28.88],"xaxis":"x","y":[27.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Bayern Munich<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","symbol":"circle","size":10},"mode":"markers","name":"Bayern Munich","orientation":"v","showlegend":true,"x":[29.09],"xaxis":"x","y":[26.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Real Madrid<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","symbol":"diamond","size":10},"mode":"markers","name":"Real Madrid","orientation":"v","showlegend":true,"x":[25.2],"xaxis":"x","y":[27.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Atl\u00e9tico de Madrid<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","symbol":"square","size":10},"mode":"markers","name":"Atl\u00e9tico de Madrid","orientation":"v","showlegend":true,"x":[30.51],"xaxis":"x","y":[28.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Name=Tottenham Hotspur<br>Average Market Value Of Players In Millions(\u00a3)=%{x}<br>Average Age Of Players=%{y}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","symbol":"x","size":10},"mode":"markers","name":"Tottenham Hotspur","orientation":"v","showlegend":true,"x":[26.14],"xaxis":"x","y":[25.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"Club Nam ...

# %% [markdown]
# Squad Size vs Market Value vs Average Age

# %%
fig = px.scatter_3d(df, x='Squad Size', y='Market Value Of Club In Millions(£)', z='Average Age Of Players', color='Club Name')
fig.show()
# Out:
# <div>                            <div id="d72d9e7e-49f6-47fc-be25-c551973259e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d72d9e7e-49f6-47fc-be25-c551973259e5")) {                    Plotly.newPlot(                        "d72d9e7e-49f6-47fc-be25-c551973259e5",                        [{"hovertemplate":"Club Name=Manchester City<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Manchester City","scene":"scene","showlegend":true,"x":[24],"y":[970.02],"z":[27.1],"type":"scatter3d"},{"hovertemplate":"Club Name=Paris Saint-Germain<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Paris Saint-Germain","scene":"scene","showlegend":true,"x":[36],"y":[891.18],"z":[26.1],"type":"scatter3d"},{"hovertemplate":"Club Name=Manchester United<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Manchester United","scene":"scene","showlegend":true,"x":[29],"y":[820.13],"z":[27.9],"type":"scatter3d"},{"hovertemplate":"Club Name=Chelsea FC<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chelsea FC","scene":"scene","showlegend":true,"x":[27],"y":[802.35],"z":[26.9],"type":"scatter3d"},{"hovertemplate":"Club Name=Liverpool FC<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Liverpool FC","scene":"scene","showlegend":true,"x":[27],"y":[779.85],"z":[27.2],"type":"scatter3d"},{"hovertemplate":"Club Name=Bayern Munich<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Bayern Munich","scene":"scene","showlegend":true,"x":[26],"y":[756.45],"z":[26.1],"type":"scatter3d"},{"hovertemplate":"Club Name=Real Madrid<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Real Madrid","scene":"scene","showlegend":true,"x":[27],"y":[680.4],"z":[27.3],"type":"scatter3d"},{"hovertemplate":"Club Name=Atl\u00e9tico de Madrid<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Atl\u00e9tico de Madrid","scene":"scene","showlegend":true,"x":[22],"y":[671.31],"z":[28.2],"type":"scatter3d"},{"hovertemplate":"Club Name=Tottenham Hotspur<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Tottenham Hotspur","scene":"scene","showlegend":true,"x":[24],"y":[627.3],"z":[25.6],"type":"scatter3d"},{"hovertemplate":"Club Name=FC Barcelona<br>Squad Size=%{x}<br>Market Value Of Club In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legen ...

# %% [markdown]
# Squad Size vs Market Value Of Top 18 Players vs Average Age

# %%
fig = px.scatter_3d(df, x='Squad Size', y='Market Value Of Top 18 Players In Millions(£)', z='Average Age Of Players', color='Club Name')
fig.show()
# Out:
# <div>                            <div id="7ef7270b-6908-4611-84f3-d3130fa48142" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ef7270b-6908-4611-84f3-d3130fa48142")) {                    Plotly.newPlot(                        "7ef7270b-6908-4611-84f3-d3130fa48142",                        [{"hovertemplate":"Club Name=Manchester City<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Manchester City","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Manchester City","scene":"scene","showlegend":true,"x":[24],"y":[920.7],"z":[27.1],"type":"scatter3d"},{"hovertemplate":"Club Name=Paris Saint-Germain<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Paris Saint-Germain","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Paris Saint-Germain","scene":"scene","showlegend":true,"x":[36],"y":[801.0],"z":[26.1],"type":"scatter3d"},{"hovertemplate":"Club Name=Manchester United<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Manchester United","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Manchester United","scene":"scene","showlegend":true,"x":[29],"y":[742.5],"z":[27.9],"type":"scatter3d"},{"hovertemplate":"Club Name=Chelsea FC<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Chelsea FC","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chelsea FC","scene":"scene","showlegend":true,"x":[27],"y":[737.1],"z":[26.9],"type":"scatter3d"},{"hovertemplate":"Club Name=Liverpool FC<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Liverpool FC","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Liverpool FC","scene":"scene","showlegend":true,"x":[27],"y":[715.95],"z":[27.2],"type":"scatter3d"},{"hovertemplate":"Club Name=Bayern Munich<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Bayern Munich","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Bayern Munich","scene":"scene","showlegend":true,"x":[26],"y":[726.21],"z":[26.1],"type":"scatter3d"},{"hovertemplate":"Club Name=Real Madrid<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Real Madrid","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Real Madrid","scene":"scene","showlegend":true,"x":[27],"y":[610.2],"z":[27.3],"type":"scatter3d"},{"hovertemplate":"Club Name=Atl\u00e9tico de Madrid<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Atl\u00e9tico de Madrid","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Atl\u00e9tico de Madrid","scene":"scene","showlegend":true,"x":[22],"y":[651.6],"z":[28.2],"type":"scatter3d"},{"hovertemplate":"Club Name=Tottenham Hotspur<br>Squad Size=%{x}<br>Market Value Of Top 18 Players In Millions(\u00a3)=%{y}<br>Average Age Of Players=%{z}<extra></extra>","legendgroup":"Tottenham Hotspur","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Tottenham Hotspur","scene":"scene","showlegend":true,"x":[24],"y":[558.0],"z":[25.6],"type":"scatter3d"},{"hovertemplate":"Club Name=FC Barcelona<br>Squad Size=%{x}<br>Market Value O ...
